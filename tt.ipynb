# %%
from sahi import AutoDetectionModel
from sahi.predict import get_sliced_prediction
from sahi.utils.cv import visualize_object_predictions
import cv2

# Load your model
detection_model = AutoDetectionModel.from_pretrained(
    model_type="ultralytics",
    model_path="best.pt",  # or last.pt
    confidence_threshold=0.3,
    device="cuda:0",  # or "cpu"
)

# %%
# Run sliced inference on an image
result = get_sliced_prediction(
    "ActionRecognition/dataset/20230609a1068.jpg",
    detection_model,
    slice_height=640,
    slice_width=640,
    overlap_height_ratio=0.35,
    overlap_width_ratio=0.35,
)

# Visualize and save
result.export_visuals(export_dir="output/")
# Out:
# Performing prediction on 15 slices.
